# %% [markdown]
# ## 지은이의 글
#
# - 프로그램과 문제 해결을 공부하면서 얻었던 **성취감**과 **즐거움**, **기쁨**을 다른 사람들에게도 전해주고 싶었기 때문. **프로그래밍의 즐거움**
#
#
# - 개인적으로 저자분께 질문했던 내용: 어떻게 하면 알고리즘을 잘할 수 있을까요? **엉덩이가 무거우면 됩니다**. 하루 15시간 이상 알고리즘 문제만 풀었습니다.

# %% [markdown]
# # 문제 해결 시작하기
#
# ## 개관
#
# - 코드 한 줄 못 짜는 사람이 많다.
# - **잘하는 사람과 못하는 사람의 생산성 차이가 스무 배**
# - 가장 근본적인 이유: 프로그래밍의 기술과 지식을 가르칠 뿐, 그것을 **스스로 응용할 수 있는 능력**을 주지 못함
# - 알고리즘을 배운 뒤 연습 문제를 풀 수는 있어도, **문제를 해결하기 위한 새로운 무언가를 고안할 수 없는 개발자**가 되는 것
# - 가장 큰 원인: 컴퓨터 교육이 실제 학문이 발전하는 방향의 반대 순서로 이루어져 있기 때문
# - 직관에 따른 시행착와와 경험이 하나씩 쌓여 학문의 기초를 이루고 나면, 학자들은 자연스럽게 학문의 뼈대가 되는 **공리**들과 **법칙**들을 만들고 **학문의 체계**를 **정리**해 나가게 됨
# - 반면 대부분의 교과서에서는 발전 과정의 **최종 결과물인 복잡한 개념**과 **도구**를 **먼저 제시**하고, **그 개념의 이론에 대해 설명**한 뒤, **곧장 연습 문제를 풀도록** 함
#
# > "그래프의 최단 거리 알고리즘은 크게 한 정점에서부터 모든 정점까지의 최단 거리를 구하는 단일 시작점 알고리즘과 모든 정점 쌍 간의 최단 거리를 구하는 모든 쌍 최단 경로 알고리즘으로 나뉜다. 단일 시작점 알고리즘의 대표적인 것으로 다익스트라 알고리즘이 있다. 의사 코드는 이렇다. 이 그래프에 대해서 알고리즘을 실행해 보자. 이 간선, 이 간선, 이 간선 순으로 완화가 이루어지므로 최단 거리를 이렇게 된다. 자, 이제 시간 복잡도를 분석해 보자"
#
# - 이 수업에서 대체 어떤 학생이 다익스트라 알고리즘이 **생겨난 배경**과 이 **알고리즘을 설계하는 데 필요했던 결정적 통찰**을 얻을 수 있을까?
# - 이런 교육형태는 학문 발전의 결과물에 대한 체계적인 지식을 학생에게 주입하는 데는 좋을지 몰라도, 문제의 답을 스스로 고안할 수 있는 학생을 기르기에는 턱없이 부족
# - 지식을 진정 자신의 것으로 만들어 활용할 수 있기 위해서는 학문이 발전하는 과정에서 일어난 **발견**과 **깨달음**을 **학생 자신이 되짚어갈 수 있어야 함**
# - 이런 경험과 깨달음을 얻기 위한 **좋은 통로**가 바로 프로그래밍 대회
# - 프로그래밍 대회들은 컴퓨터 과학 전반에 걸쳐 널리 쓰이는 각종 알고리즘과 자료구조들을 이용해 주어진 문제들을 **해결**하고 **구현하는 능력**을 겨루는 대회
# - 잘 알려진 알고리즘들을 베껴 쓰기만 하면 해결할 수 있는 문제만 있는 것이 아니라 알고리즘에 사용된 **원칙들을 이해하고 변형**해야 풀 수 있는 문제들이 많이 출제되기 때문에 이런 주제들을 깊이 이해하는데 큰 도움이 됨
# - **공정**하고 **즉각적인 피드백**이 주어지기 때문에 혼자서도 훨씬 재미있게 공부할 수 있음
# - **각종 알고리즘 설계 기법**과 **자료 구조**를 직관적으로 이해하고, 나아가 알고리즘 문제 해결 능력을 키울 수 있도록 구성함
# - 각 기법이 생겨난 **배경**과 **이유**, 그리고 기법을 만들기 위해 **필요한 과정**을 자세히 다룸
# - 연습 문제는 실제 프로그래밍 대회 문제로 구성
# - 해당 장에서 배운 기법을 직접적으로 적용하거나 변형해 보면서 이들에 대한 **직관**을 얻을 수 있도록 설계함
# - 여러 문제를(어렵게) 풀어가는 과정에서 **다양한 개념과 구조들을 경험적으로 이해**할 수 있도록 하는 것이 이 책의 **목표**
# - 프로그래밍은 **어려운 만큼 재미있는 직업**
# - 문제를 푸는 것도 그렇다.
# - 문제가 풀리지 않을 때의 괴로움은 문제가 풀렸을 때의 기쁨과 그 과정에서 얻은 통찰을 자신의 것으로 만들었을 때 느끼는 뿌듯함에 비하면 아무것도 아님
# - 그렇게 **즐겁게** 이 책을 읽어나갈 수 있기를 기대함

# %% [markdown]
# ## 문제 해결과 프로그래밍 대회
#
# ### 1.1 도입
#
# - 프로그래머라는 하나의 직업명으로 부르기 힘들만큼 다양한 종류의 프로그래머들이 존재
# - 이런 분야간의 차이를 뛰어넘는 좋은 개발자의 조건이 존재할까?
#
# #### 프로그래밍은 문제해결이다
#
# - 프로그래밍을 하기 위해서는 많은 것을 알아야 함
# - 프로그래밍 언어의 특성, 프로그래밍이 동작할 하드웨어와 운영체제에 관한 지식, 사용하고 있는 라이브러리들에 대한 유의사항
# - 프로그램이 사용할 수 있는 **최대 메모리**, 사용자가 답답해하지 않게 하기 위한 **시간 제한**, **재사용**성이 높은 간결한 코드 작성해야 함
# - 많은 **제약 조건**과 **요구사항**을 **이해**하고 **최선의 방법**을 **찾아내는 능력**은 분야를 막론하고 좋은 프로그래머가 되기 위해 필수적. 문제 해결 능력이라 부름
# - 이들을 연결해서 **큰 그림을 만드는 능력**
# - 문제 해결 능력을 훈련하기란 굉장히 어렵다. 문제 해결 능력은 **추상적인 기술**이기 때문
# - 새로운 언어와 프레임워크, 개발 방법들을 계속 배워 나가지만 **이들을 조합하는 방법**에 대해서는 배울 곳이 없음
# - 좋은 프로그래머가 되기 위한 좀 더 나은 방법은 없을까?

# %% [markdown]
# ### 1.2 프로그래밍 대회
#
# - 프로그래밍 대회에 참가하는 것은 문제 해결 기술을 연마하기에 가장 좋ㅇ느 방법
# - 주로 짧은 요구사항을 제시하고, 이에 맞는 프로그램을 시간 안에 빠르게 작성하는 능력을 겨루는 대회
# - 이때의 요구사항이란 현업에서 접하는 형태의 요구사항이 아니라 대개 '어떤 값을 읽어들여 어떤 값을 계산하는 프로그램을 작성하시오' 라는 형태를 갖음

# %%
from IPython.display import IFrame

# %%
IFrame('https://www.algospot.com/judge/problem/read/FESTIVAL', 
       width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height=800"
#             src="https://www.algospot.com/judge/problem/read/FESTIVAL"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### 프로그래밍 대회에서 배울 수 있는 것들
#
# - 프로그래밍 대회의 문제들은 현업에서의 사양서와 아주 다르다
#
#
# 1. 프로그래밍 대회에서 작성하는 프로그램들은 그래픽 인터페이스 등을 전혀 사용하지 않으며, 단순히 텍스트 파일을 읽어들이고 텍스트 파일을 출력함. 이렇기 군더더기가 없기 때문에 참가자는 다른 데 정신을 빼앗기지 않고 **문제를 해결하는 데에만 집중**할 수 있음
# 2. 명시적인 **시간 제한**과 **메모리 제한**이 있음. 프로그래밍 대회에서는 참가자가 제출한 프로그램이 평가용 입력을 처리하다가 제한 시간을 초과하거나 제한보다 많은 메모리를 사용하면 답의 정확성과 관련없이 틀린 답으로 처리함. 그런데 많은 프로그래밍 대회 문제들은 **계산 집중적**이기 때문에 적절한 알고리즘과 자료 구조를 사용하지 않으면 시간 제한 내에 알고리즘을 신중하게 설계해야 함. 때문에 프로그래밍 대회는 **다양한 알고리즘 설계 기법**과 **자료 구조**를 직접 사용해 볼 수 있는 계기가 됨. 잘 알려진 알고리즘들을 베껴 쓰기만 하면 해결할 수 있는 문제만 있는 것이 아니라 알고리즘에 사용된 **원칙들**을 이해하고 변형해야 풀 수 있는 문제들이 많이 출제되기 떄문에 이런 주제들을 깊이 이해하는 데 큰 도움이 됨
# 3. **정답**과 **오답의 여부**가 훨씬 명확히 가려짐. 현업에서는 대게 코드의 정당성을 **단위 테스트**나 **상호 간 코드 리뷰**로 검증하는데, 이런 방법으로는 잘해봐야 한두 개의 입력을 가지고 프로그램을 시험해 보기 마련. 그러나 대회에서는 **훨씬 크고 다양한 입력**에 대해 **정답을 계산하는지 확인**하므로 오류의 존재를 모르고 넘어갈 가능성이 훨씬 적음. 게다가 대부분의 프로그램 대회에서는 **프로그램의 정답 여부**를 대회가 끝난 뒤 **바로 알려주며**, 일부 대회에서는 제출하자마자 알려주기도 함. 자신이 작성한 코드에 대해 이렇게 **빠르고 객관적인 피드백**을 받는 것은 **예외없고 정확한 프로그램을 짜는 아주 좋은 훈련**이 됨
# 4. 제출한 프로그램의 **실행 시간**이나 **메모리 사용량** 관련 정보가 실시간으로 제공되기 때문에, 프로그램을 고쳐 가며 **작은 변경**이 프로그램의 **효율성에 미치는 영향을 직접 체험**해 볼 수 있음. 논리적 구조가 복잡한 프로그램의 수행 성능을 예측하는 데 익숙해지기 때문에 실무에서 **퍼포먼스**가 중요한 프로그램을 짜는 데도 큰 도움이 됨
# 5. 프로그래밍 대회에 제출하는 프로그램들은 대개 규모가 작아 각 문제를 풀 때마다 처음부터 다시 짜게 됨. 이런 특성은 평소 대형 프로젝트에서 간과했던 **프로그램의 작은 부분에 집중**할 수 있는 계기를 만들어 줌. 커다란 프로젝트에서 작업할 떄는 **코드의 구조를 변경하기도 어렵고**, 큰 그림을 위해 프로그램의 우아함을 희생해야 할 때도 있음. 그러나 대회를 위한 작은 코드를 작성할 떄는 이런 걱정없이 간결하면서 우아한 프로그램을 짜는 데 시간을 투자할 수 있으므로, 좋은 코드를 작성하는 좋은 연습이 됨
# 6. 프로그래밍 대회에서는 여러 사람이 **경쟁하는 환경**에서 코드를 작성하게 됨. 사람에 따라 **경쟁느 실력을 늘리기 위한 좋은 동기**가 되기도 함. 많은 프로그래밍 대회에서는 대회가 끝난 후 제출된 소스를 **모두 공개**한다는 점도 주목할 만하다. 현업에서는 2 사람 이상이 같은 일을 하는 코드를 동시에 작성하는 일이 거의 없지만, 대회에서는 모든 사람이 같은 문제를 풀기 때문에 **전세계의 고수 프로그래머**들이 짠 코드를 **직접 보고 자신이 짠 코드와 비교**해 볼 수 있는 기회
#
#
# - 이런 특성들은 프로그래밍 작업에서 **문제 해결을 수련**하기 위해 **필수적인 요소만**을 남겨 놓고 나머지를 전부 제외한 것이나 마찬가지. 덕분에 프로그래밍 대회는 **문제 해결을 공부**하기에 아주 적합한 환경
# - 한 번쯤 해 볼 만하다고 느껴지나요?

# %% [markdown]
# ### 1.3 이 책을 읽는 방법
#
# #### 이 책의 구성
#
# - 기초 지식: 문제 해결 방법론, 코딩과 디버깅에 대한 주의사항, 알고리즘의 정당성 증명과 효율성 분석
# - 이 책의 나머지 부분: 알고리즘 설계 기법, 자료구조 등 프로그래밍 대회 문제 해결에 필요한 기술들 소개
# - 각 기법이 도입된 계기와 설계 과정들에 대해 소개, 이 기법들을 직접 혹은 변형해서 적용해 볼 수 있는 연습 문제 포함
# - 연습 문제와 그 풀이 큰 비중을 두고 있음. 연습 문제들을 단순히 본문의 연장처럼 읽어 내려가지 말고, 멈춰서 가능한 한 **직접 풀어보려고** 시도하는 것이 좋음. 연습 문제를 풀어본 사람만이 **자신의 경험**과 **책에 있는 풀이를 비교**하면서 더 많은 것을 배울 수 있기 때문
# - 이 책의 연습 문제들은 모두 온라인 채점 사이트 [알고스팟](http://algospot.com)에서 실제 대회와 비슷한 환경에서 채점 받을 수 있음
# - 문제를 직접 해결한 뒤에는 자신이 작성한 코드와 책에 실린 풀이 소스 코드를 비교해 보는 것이 좋음
# - 이 책의 모든 소스코드는 효율성을 잃지 않는 범위 내에서 최대한 간결하게 작성되었음
# - 자신이 푼 알고리즘과 비슷한지, 같다면 같은 알고리즘을 어떻게 구현했는지도 비교해 보고 더 좋은 방법을 찾아내려 노력해 보세요
#
# #### 필요한 배경 지식
#
# - 학부생이 주 독자층
# - 수학이나 전산학 지식들은 대부분 고등학교 수학 과목이나 컴퓨터 과학과의 입문 수업에서 다루는 것들임
# - 때문에 고등학교 수학 과정을 이수했으며 C++와 STL을 사용할 수 있다면 이 책을 읽기 위해 미리 더 알아야 할 것은 없음
#
# #### 입문자를 위한 권장 사항
#
# - **가장 중요**하고 **기초적인 주제**만을 우선 소화한 뒤 다시 읽으며 **빈 곳을 메꿔가는 쪽**이 편함
#
# 장 번호 | 장 제목
# --- | ---
# 2 | 문제 해결 전략
# 3 | 코딩과 디버깅
# 4 | 알고리즘의 시간 복잡도 분석
# 6 | 무식하게 풀기
# 7 | 분할 정복
# 8 | 동적 계획법
# 18 | 선형 자료 구조
# 19 | 큐와 스택, 데크
# 21 | 트리의 구현과 순회
# 22 | 이진 검색 트리
# 23 | 우선순위 큐와 힙
# 27 | 그래프의 표현과 정의
# 28 | 그래프의 깊이 우선 탐색
# 29 | 그래프의 너비 우선 탐색
# 30 | 최단 경로 알고리즘

# %% [markdown]
# ### 1.4 국내에서 참가할 수 있는 프로그래밍 대회
#
# - 알고리즘 문제 풀이 능력이 여러 소프트웨어 대기업들의 중요한 채용 기준중 하나가 되면서 일반인을 대상으로 하는 대회들도 생겨남
# -
