# %% [markdown]
# # How to use R kernel in IPython Notebook
#
# ## Original link
#
# - [Interactive R Notebooks on powerful cloud hardware](http://blog.revolutionanalytics.com/2015/01/interactive-r-notebooks-on-powerful-cloud-hardware.html)

# %% [markdown]
# ## Logic
#
# 0. Install rpy2
# 1. Create Profile
# 2. Write rkernel.py
# 3. Run rkernel

# %% [markdown]
# ### 1. Install rpy2
#
# >$ pip install rpy2
#
# ### 2. Create Profile
#
# <img src="files/images/01_create_profile.png" />
#
# ### 3. Write rkernel.py
#
# #### 현재 디렉토리 확인, rkernel.py 작성, ipython notebook --profile=rkernel
#
# <img src="files/images/02_write_rkernel.png" />
#
# #### rkernel.py 작성
#
# <img src="files/images/03_write_rkernel2.png" />
#
# ### 4. run rkernel
#
# - http://localhost:8889/
# <img src="files/images/04_run_rkernel.png" />

# %% [markdown]
# ## Running Rkernel

# %%
X=c(1,4,5,7); sd(X); mean(X)
# Out:
# [1] 4.25

# %%
Y = c(2,4,3,9)
summary(lm(Y~X))
# Out:
# Call:
# lm(formula = Y ~ X)
#
# Residuals:
#     1     2     3     4
#  0.88 -0.24 -2.28  1.64
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.0800     2.3000   0.035    0.975
# X             1.0400     0.4822   2.157    0.164
#
# Residual standard error: 2.088 on 2 degrees of freedom
# Multiple R-squared:  0.6993,	Adjusted R-squared:  0.549
# F-statistic: 4.651 on 1 and 2 DF,  p-value: 0.1638

# %%
plot(X, Y)
